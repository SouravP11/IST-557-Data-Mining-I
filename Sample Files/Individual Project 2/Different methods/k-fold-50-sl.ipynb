# %% [markdown]
# ## Import Statements

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from torch.optim.lr_scheduler import StepLR

# %% [markdown]
# ## Device Config

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device : {device}")
# Out:
# Device : cuda

# %% [markdown]
# ## Set the Seed for reproducibility

# %%
# Set the random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Define number of folds

# %%
# Define the number of folds (k)
k = 5  # You can change this value as needed

# %% [markdown]
# ## CNN

# %%
# Define your CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(512, 10)  # 10 classes for CIFAR-10
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x
    
# Initialize your model
model = CNN()
model.to(device)
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Data Prep

# %%
# Define data augmentation and preprocessing transformations
batch_size = 20
augmentation_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load the CIFAR-10 dataset
augmented_train_data = torchvision.datasets.CIFAR10('data', train=True, download=True, transform=augmentation_transform)

# Split the dataset into k folds
fold_size = len(augmented_train_data) // k
fold_datasets = [torch.utils.data.Subset(augmented_train_data, range(i * fold_size, (i + 1) * fold_size)) for i in range(k)]

# 10 classes in total
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Test set

# %%
# load test data (note that the data has been transformed already)
test_images = torch.load('/kaggle/input/fall-2023-ist-557-individual-project-ii/test_image.pt')

# %% [markdown]
# ## Optimizer, Loss Function, and Step scheduler

# %%
# Initialize optimizer and loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Define the learning rate scheduler
step_size = 10  # Adjust this as needed
gamma = 0.5     # Adjust this as needed
scheduler = StepLR(optimizer, step_size=step_size, gamma=gamma)

# %% [markdown]
# ## Training Loop

# %%
# Lists to store performance metrics
all_fold_train_losses = []
all_fold_val_losses = []




for fold_idx, fold_data in enumerate(fold_datasets):
    print(f"Training fold {fold_idx + 1}/{k}")

    # Create data loaders for training and validation
    validation_set = fold_data
    training_sets = [f for i, f in enumerate(fold_datasets) if i != fold_idx]
    training_set = torch.utils.data.ConcatDataset(training_sets)

    train_loader = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_loader = DataLoader(validation_set, batch_size=batch_size, shuffle=False, num_workers=2)

    # Training loop
    train_losses = []
    val_losses = []
    total_epoch = 50  # You can change the number of epochs as needed

    for epoch in range(total_epoch):
        train_loss = 0.0
        valid_loss = 0.0
        
        # Train the model
        model.train()
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * data.size(0)

        # Validate the model
        model.eval()
        for valid_data, valid_target in valid_loader:
            valid_data, valid_target = valid_data.to(device), valid_target.to(device)
            valid_output = model(valid_data)
            loss = criterion(valid_output, valid_target)
            valid_loss += loss.item() * valid_data.size(0)

        avg_val_loss = valid_loss / len(validation_set)
        avg_train_loss = train_loss / len(training_set)

        val_losses.append(avg_val_loss)
        train_losses.append(avg_train_loss)
        
        scheduler.step()

        print(f'Epoch: {epoch + 1}/{total_epoch} \tTraining Loss: {avg_train_loss:.6f} \tValidation Loss: {avg_val_loss:.6f}')

    print(f'Finished Training for fold {fold_idx + 1}/{k}')
    all_fold_train_losses.append(train_losses)
    all_fold_val_losses.append(val_losses)

# Calculate and print the average performance metrics over all folds
avg_train_losses = np.mean(all_fold_train_losses, axis=0)
avg_val_losses = np.mean(all_fold_val_losses, axis=0)

# Plot the training and validation loss curves
import matplotlib.pyplot as plt

plt.plot(range(1, total_epoch + 1), avg_train_losses, label='Average Train Loss', marker='o')
plt.plot(range(1, total_epoch + 1), avg_val_losses, label='Average Validation Loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Average Training and Validation Loss Curves ({k}-fold cross-validation)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training fold 1/5
# Epoch: 1/50 	Training Loss: 1.431898 	Validation Loss: 1.225566
# Epoch: 2/50 	Training Loss: 1.088859 	Validation Loss: 1.026669
# Epoch: 3/50 	Training Loss: 0.930531 	Validation Loss: 1.205843
# Epoch: 4/50 	Training Loss: 0.827376 	Validation Loss: 0.858456
# Epoch: 5/50 	Training Loss: 0.756709 	Validation Loss: 0.795726
# Epoch: 6/50 	Training Loss: 0.700778 	Validation Loss: 0.764145
# Epoch: 7/50 	Training Loss: 0.654070 	Validation Loss: 0.624996
# Epoch: 8/50 	Training Loss: 0.620863 	Validation Loss: 0.679319
# Epoch: 9/50 	Training Loss: 0.582547 	Validation Loss: 0.607300
# Epoch: 10/50 	Training Loss: 0.556874 	Validation Loss: 0.574436
# Epoch: 11/50 	Training Loss: 0.469978 	Validation Loss: 0.526776
# Epoch: 12/50 	Training Loss: 0.456457 	Validation Loss: 0.511723
# Epoch: 13/50 	Training Loss: 0.436115 	Validation Loss: 0.488915
# Epoch: 14/50 	Training Loss: 0.426738 	Validation Loss: 0.553799
# Epoch: 15/50 	Training Loss: 0.416239 	Validation Loss: 0.494403
# Epoch: 16/50 	Training Loss: 0.406359 	Validation Loss: 0.461532
# Epoch: 17/50 	Training Loss: 0.393633 	Validation Loss: 0.466580
# Epoch: 18/50 	Training Loss: 0.381962 	Validation Loss: 0.519806
# Epoch: 19/50 	Training Loss: 0.375323 	Validation Loss: 0.493942
# Epoch: 20/50 	Training Loss: 0.363846 	Validation Loss: 0.498343
# Epoch: 21/50 	Training Loss: 0.318567 	Validation Loss: 0.420431
# Epoch: 22/50 	Training Loss: 0.308291 	Validation Loss: 0.431549
# Epoch: 23/50 	Training Loss: 0.295689 	Validation Loss: 0.420839
# Epoch: 24/50 	Training Loss: 0.294701 	Validation Loss: 0.406783
# Epoch: 25/50 	Training Loss: 0.287489 	Validation Loss: 0.401540
# Epoch: 26/50 	Training Loss: 0.280604 	Validation Loss: 0.413729
# Epoch: 27/50 	Training Loss: 0.275042 	Validation Loss: 0.409205
# Epoch: 28/50 	Training Loss: 0.273100 	Validation Loss: 0.409770
# Epoch: 29/50 	Training Loss: 0.266240 	Validation Loss: 0.404171
# Epoch: 30/50 	Training Loss: 0.262898 	Validation Loss: 0.405087
# Epoch: 31/50 	Training Loss: 0.234327 	Validation Loss: 0.386814
# Epoch: 32/50 	Training Loss: 0.228807 	Validation Loss: 0.382055
# Epoch: 33/50 	Training Loss: 0.224793 	Validation Loss: 0.391663
# Epoch: 34/50 	Training Loss: 0.224936 	Validation Loss: 0.387462
# Epoch: 35/50 	Training Loss: 0.214911 	Validation Loss: 0.384562
# Epoch: 36/50 	Training Loss: 0.213743 	Validation Loss: 0.394445
# Epoch: 37/50 	Training Loss: 0.211308 	Validation Loss: 0.390229
# Epoch: 38/50 	Training Loss: 0.211667 	Validation Loss: 0.386953
# Epoch: 39/50 	Training Loss: 0.206517 	Validation Loss: 0.376512
# Epoch: 40/50 	Training Loss: 0.202866 	Validation Loss: 0.388684
# Epoch: 41/50 	Training Loss: 0.194076 	Validation Loss: 0.373418
# Epoch: 42/50 	Training Loss: 0.188739 	Validation Loss: 0.378222
# Epoch: 43/50 	Training Loss: 0.188273 	Validation Loss: 0.370192
# Epoch: 44/50 	Training Loss: 0.182994 	Validation Loss: 0.368506
# Epoch: 45/50 	Training Loss: 0.182646 	Validation Loss: 0.388587
# Epoch: 46/50 	Training Loss: 0.181404 	Validation Loss: 0.366065
# Epoch: 47/50 	Training Loss: 0.181201 	Validation Loss: 0.371424
# Epoch: 48/50 	Training Loss: 0.179820 	Validation Loss: 0.378736
# Epoch: 49/50 	Training Loss: 0.180561 	Validation Loss: 0.382599
# Epoch: 50/50 	Training Loss: 0.177347 	Validation Loss: 0.374036
# Finished Training for fold 1/5
# Training fold 2/5
# Epoch: 1/50 	Training Loss: 0.231465 	Validation Loss: 0.131961
# Epoch: 2/50 	Training Loss: 0.224679 	Validation Loss: 0.136124
# Epoch: 3/50 	Training Loss: 0.220104 	Validation Loss: 0.137627
# Epoch: 4/50 	Training Loss: 0.219876 	Validation Loss: 0.140244
# Epoch: 5/50 	Training Loss: 0.219588 	Validation Loss: 0.142341
# Epoch: 6/50 	Training Loss: 0.214720 	Validation Loss: 0.149132
# Epoch: 7/50 	Training Loss: 0.215851 	Validation Loss: 0.141854
# Epoch: 8/50 	Training Loss: 0.215805 	Validation Loss: 0.139351
# Epoch: 9/50 	Training Loss: 0.212983 	Validation Loss: 0.138631
# Epoch: 10/50 	Training Loss: 0.207624 	Validation Loss: 0.139725
# Epoch: 11/50 	Training Loss: 0.207058 	Validation Loss: 0.140437
# Epoch: 12/50 	Training Loss: 0.201790 	Validation Loss: 0.147580
# Epoch: 13/50 	Training Loss: 0.203689 	Validation Loss: 0.138980
# Epoch: 14/50 	Training Loss: 0.204076 	Validation Loss: 0.141497
# Epoch: 15/50 	Training Loss: 0.202173 	Validation Loss: 0.140624
# Epoch: 16/50 	Training Loss: 0.200988 	Validation Loss: 0.142412
# Epoch: 17/50 	Training Loss: 0.201531 	Validation Loss: 0.137031
# Epoch: 18/50 	Training Loss: 0.197850 	Validation Loss: 0.135150
# Epoch: 19/50 	Training Loss: 0.198546 	Validation Loss: 0.135515
# Epoch: 20/50 	Training Loss: 0.197819 	Validation Loss: 0.146593
# Epoch: 21/50 	Training Loss: 0.193682 	Validation Loss: 0.142525
# Epoch: 22/50 	Training Loss: 0.199480 	Validation Loss: 0.135475
# Epoch: 23/50 	Training Loss: 0.198263 	Validation Loss: 0.145931
# Epoch: 24/50 	Training Loss: 0.192439 	Validation Loss: 0.140277
# Epoch: 25/50 	Training Loss: 0.196040 	Validation Loss: 0.148005
# Epoch: 26/50 	Training Loss: 0.190713 	Validation Loss: 0.138620
# Epoch: 27/50 	Training Loss: 0.192542 	Validation Loss: 0.145559
# Epoch: 28/50 	Training Loss: 0.190797 	Validation Loss: 0.144142
# Epoch: 29/50 	Training Loss: 0.193600 	Validation Loss: 0.135982
# Epoch: 30/50 	Training Loss: 0.189757 	Validation Loss: 0.148143
# Epoch: 31/50 	Training Loss: 0.191228 	Validation Loss: 0.142480
# Epoch: 32/50 	Training Loss: 0.188432 	Validation Loss: 0.143779
# Epoch: 33/50 	Training Loss: 0.190902 	Validation Loss: 0.138915
# Epoch: 34/50 	Training Loss: 0.190339 	Validation Loss: 0.144539
# Epoch: 35/50 	Training Loss: 0.192132 	Validation Loss: 0.144889
# Epoch: 36/50 	Training Loss: 0.189151 	Validation Loss: 0.143841
# Epoch: 37/50 	Training Loss: 0.191130 	Validation Loss: 0.140542
# Epoch: 38/50 	Training Loss: 0.189814 	Validation Loss: 0.143337
# Epoch: 39/50 	Training Loss: 0.188796 	Validation Loss: 0.144660
# Epoch: 40/50 	Training Loss: 0.190542 	Validation Loss: 0.143879
# Epoch: 41/50 	Training Loss: 0.185899 	Validation Loss: 0.139524
# Epoch: 42/50 	Training Loss: 0.191459 	Validation Loss: 0.147123
# Epoch: 43/50 	Training Loss: 0.188868 	Validation Loss: 0.142654
# Epoch: 44/50 	Training Loss: 0.189852 	Validation Loss: 0.143964
# Epoch: 45/50 	Training Loss: 0.186810 	Validation Loss: 0.142186
# Epoch: 46/50 	Training Loss: 0.185328 	Validation Loss: 0.147596
# Epoch: 47/50 	Training Loss: 0.187760 	Validation Loss: 0.141911
# Epoch: 48/50 	Training Loss: 0.187288 	Validation Loss: 0.143019
# Epoch: 49/50 	Training Loss: 0.188659 	Validation Loss: 0.146059
# Epoch: 50/50 	Training Loss: 0.184896 	Validation Loss: 0.142528
# Finished Training for fold 2/5
# Training fold 3/5
# Epoch: 1/50 	Training Loss: 0.195754 	Validation Loss: 0.110933
# Epoch: 2/50 	Training Loss: 0.196428 	Validation Loss: 0.113791
# Epoch: 3/50 	Training Loss: 0.193844 	Validation Loss: 0.111274
# Epoch: 4/50 	Training Loss: 0.196365 	Validation Loss: 0.115188
# Epoch: 5/50 	Training Loss: 0.197806 	Validation Loss: 0.110013
# Epoch: 6/50 	Training Loss: 0.195930 	Validation Loss: 0.115501
# Epoch: 7/50 	Training Loss: 0.193073 	Validation Loss: 0.111139
# Epoch: 8/50 	Training Loss: 0.194352 	Validation Loss: 0.110811
# Epoch: 9/50 	Training Loss: 0.192709 	Validation Loss: 0.116071
# Epoch: 10/50 	Training Loss: 0.199232 	Validation Loss: 0.114338
# Epoch: 11/50 	Training Loss: 0.192419 	Validation Loss: 0.109913
# Epoch: 12/50 	Training Loss: 0.193536 	Validation Loss: 0.111304
# Epoch: 13/50 	Training Loss: 0.194239 	Validation Loss: 0.115697
# Epoch: 14/50 	Training Loss: 0.195859 	Validation Loss: 0.116345
# Epoch: 15/50 	Training Loss: 0.191023 	Validation Loss: 0.111771
# Epoch: 16/50 	Training Loss: 0.192158 	Validation Loss: 0.118013
# Epoch: 17/50 	Training Loss: 0.195680 	Validation Loss: 0.116330
# Epoch: 18/50 	Training Loss: 0.195890 	Validation Loss: 0.111291
# Epoch: 19/50 	Training Loss: 0.191426 	Validation Loss: 0.117567
# Epoch: 20/50 	Training Loss: 0.197600 	Validation Loss: 0.115687
# Epoch: 21/50 	Training Loss: 0.194269 	Validation Loss: 0.113987
# Epoch: 22/50 	Training Loss: 0.193310 	Validation Loss: 0.115673
# Epoch: 23/50 	Training Loss: 0.196468 	Validation Loss: 0.114485
# Epoch: 24/50 	Training Loss: 0.191663 	Validation Loss: 0.119294
# Epoch: 25/50 	Training Loss: 0.195120 	Validation Loss: 0.110071
# Epoch: 26/50 	Training Loss: 0.195751 	Validation Loss: 0.114181
# Epoch: 27/50 	Training Loss: 0.194504 	Validation Loss: 0.111616
# Epoch: 28/50 	Training Loss: 0.193291 	Validation Loss: 0.113788
# Epoch: 29/50 	Training Loss: 0.191246 	Validation Loss: 0.114215
# Epoch: 30/50 	Training Loss: 0.196092 	Validation Loss: 0.113343
# Epoch: 31/50 	Training Loss: 0.194104 	Validation Loss: 0.114794
# Epoch: 32/50 	Training Loss: 0.195773 	Validation Loss: 0.113044
# Epoch: 33/50 	Training Loss: 0.192427 	Validation Loss: 0.110226
# Epoch: 34/50 	Training Loss: 0.193920 	Validation Loss: 0.117887
# Epoch: 35/50 	Training Loss: 0.195543 	Validation Loss: 0.118952
# Epoch: 36/50 	Training Loss: 0.195287 	Validation Loss: 0.114443
# Epoch: 37/50 	Training Loss: 0.196661 	Validation Loss: 0.110476
# Epoch: 38/50 	Training Loss: 0.193253 	Validation Loss: 0.111222
# Epoch: 39/50 	Training Loss: 0.192827 	Validation Loss: 0.113967
# Epoch: 40/50 	Training Loss: 0.194240 	Validation Loss: 0.122233
# Epoch: 41/50 	Training Loss: 0.194914 	Validation Loss: 0.110162
# Epoch: 42/50 	Training Loss: 0.192514 	Validation Loss: 0.113290
# Epoch: 43/50 	Training Loss: 0.194309 	Validation Loss: 0.112423
# Epoch: 44/50 	Training Loss: 0.192943 	Validation Loss: 0.113158
# Epoch: 45/50 	Training Loss: 0.194954 	Validation Loss: 0.112097
# Epoch: 46/50 	Training Loss: 0.191406 	Validation Loss: 0.114500
# Epoch: 47/50 	Training Loss: 0.194650 	Validation Loss: 0.116862
# Epoch: 48/50 	Training Loss: 0.195686 	Validation Loss: 0.119926
# Epoch: 49/50 	Training Loss: 0.191915 	Validation Loss: 0.113956
# Epoch: 50/50 	Training Loss: 0.196588 	Validation Loss: 0.113116
# Finished Training for fold 3/5
# Training fold 4/5
# Epoch: 1/50 	Training Loss: 0.189748 	Validation Loss: 0.118499
# Epoch: 2/50 	Training Loss: 0.191561 	Validation Loss: 0.114859
# Epoch: 3/50 	Training Loss: 0.193178 	Validation Loss: 0.113551
# Epoch: 4/50 	Training Loss: 0.191138 	Validation Loss: 0.115363
# Epoch: 5/50 	Training Loss: 0.192300 	Validation Loss: 0.116610
# Epoch: 6/50 	Training Loss: 0.187842 	Validation Loss: 0.121427
# Epoch: 7/50 	Training Loss: 0.192752 	Validation Loss: 0.120922
# Epoch: 8/50 	Training Loss: 0.190083 	Validation Loss: 0.117980
# Epoch: 9/50 	Training Loss: 0.191775 	Validation Loss: 0.116631
# Epoch: 10/50 	Training Loss: 0.189943 	Validation Loss: 0.118211
# Epoch: 11/50 	Training Loss: 0.193511 	Validation Loss: 0.115510
# Epoch: 12/50 	Training Loss: 0.192066 	Validation Loss: 0.116659
# Epoch: 13/50 	Training Loss: 0.190575 	Validation Loss: 0.119327
# Epoch: 14/50 	Training Loss: 0.193862 	Validation Loss: 0.112763
# Epoch: 15/50 	Training Loss: 0.191559 	Validation Loss: 0.115944
# Epoch: 16/50 	Training Loss: 0.188440 	Validation Loss: 0.118525
# Epoch: 17/50 	Training Loss: 0.190903 	Validation Loss: 0.121518
# Epoch: 18/50 	Training Loss: 0.190767 	Validation Loss: 0.118260
# Epoch: 19/50 	Training Loss: 0.193962 	Validation Loss: 0.117530
# Epoch: 20/50 	Training Loss: 0.192190 	Validation Loss: 0.117984
# Epoch: 21/50 	Training Loss: 0.195148 	Validation Loss: 0.118035
# Epoch: 22/50 	Training Loss: 0.191767 	Validation Loss: 0.117757
# Epoch: 23/50 	Training Loss: 0.192668 	Validation Loss: 0.115222
# Epoch: 24/50 	Training Loss: 0.193455 	Validation Loss: 0.117036
# Epoch: 25/50 	Training Loss: 0.195513 	Validation Loss: 0.116296
# Epoch: 26/50 	Training Loss: 0.190543 	Validation Loss: 0.116662
# Epoch: 27/50 	Training Loss: 0.192695 	Validation Loss: 0.123767
# Epoch: 28/50 	Training Loss: 0.188033 	Validation Loss: 0.118747
# Epoch: 29/50 	Training Loss: 0.193542 	Validation Loss: 0.116398
# Epoch: 30/50 	Training Loss: 0.192826 	Validation Loss: 0.116832
# Epoch: 31/50 	Training Loss: 0.189611 	Validation Loss: 0.115390
# Epoch: 32/50 	Training Loss: 0.193256 	Validation Loss: 0.116972
# Epoch: 33/50 	Training Loss: 0.193296 	Validation Loss: 0.119310
# Epoch: 34/50 	Training Loss: 0.189989 	Validation Loss: 0.118877
# Epoch: 35/50 	Training Loss: 0.194165 	Validation Loss: 0.114199
# Epoch: 36/50 	Training Loss: 0.193218 	Validation Loss: 0.118199
# Epoch: 37/50 	Training Loss: 0.193325 	Validation Loss: 0.118465
# Epoch: 38/50 	Training Loss: 0.192669 	Validation Loss: 0.120402
# Epoch: 39/50 	Training Loss: 0.192594 	Validation Loss: 0.114484
# Epoch: 40/50 	Training Loss: 0.192945 	Validation Loss: 0.118254
# Epoch: 41/50 	Training Loss: 0.189733 	Validation Loss: 0.114060
# Epoch: 42/50 	Training Loss: 0.193224 	Validation Loss: 0.118404
# Epoch: 43/50 	Training Loss: 0.190687 	Validation Loss: 0.121882
# Epoch: 44/50 	Training Loss: 0.193199 	Validation Loss: 0.119122
# Epoch: 45/50 	Training Loss: 0.188786 	Validation Loss: 0.118215
# Epoch: 46/50 	Training Loss: 0.189637 	Validation Loss: 0.117116
# Epoch: 47/50 	Training Loss: 0.189700 	Validation Loss: 0.118317
# Epoch: 48/50 	Training Loss: 0.187919 	Validation Loss: 0.115361
# Epoch: 49/50 	Training Loss: 0.189084 	Validation Loss: 0.114832
# Epoch: 50/50 	Training Loss: 0.190783 	Validation Loss: 0.119066
# Finished Training for fold 4/5
# Training fold 5/5
# Epoch: 1/50 	Training Loss: 0.196673 	Validation Loss: 0.110940
# Epoch: 2/50 	Training Loss: 0.195726 	Validation Loss: 0.112291
# Epoch: 3/50 	Training Loss: 0.194142 	Validation Loss: 0.108996
# Epoch: 4/50 	Training Loss: 0.196696 	Validation Loss: 0.108280
# Epoch: 5/50 	Training Loss: 0.194013 	Validation Loss: 0.106437
# Epoch: 6/50 	Training Loss: 0.192884 	Validation Loss: 0.110499
# Epoch: 7/50 	Training Loss: 0.196073 	Validation Loss: 0.112334
# Epoch: 8/50 	Training Loss: 0.194898 	Validation Loss: 0.108118
# Epoch: 9/50 	Training Loss: 0.194905 	Validation Loss: 0.108056
# Epoch: 10/50 	Training Loss: 0.193805 	Validation Loss: 0.112717
# Epoch: 11/50 	Training Loss: 0.196099 	Validation Loss: 0.114633
# Epoch: 12/50 	Training Loss: 0.190447 	Validation Loss: 0.109587
# Epoch: 13/50 	Training Loss: 0.195144 	Validation Loss: 0.105017
# Epoch: 14/50 	Training Loss: 0.196766 	Validation Loss: 0.109743
# Epoch: 15/50 	Training Loss: 0.195672 	Validation Loss: 0.108772
# Epoch: 16/50 	Training Loss: 0.194562 	Validation Loss: 0.113156
# Epoch: 17/50 	Training Loss: 0.194949 	Validation Loss: 0.110427
# Epoch: 18/50 	Training Loss: 0.195182 	Validation Loss: 0.112057
# Epoch: 19/50 	Training Loss: 0.195465 	Validation Loss: 0.112684
# Epoch: 20/50 	Training Loss: 0.193133 	Validation Loss: 0.114860
# Epoch: 21/50 	Training Loss: 0.193598 	Validation Loss: 0.112592
# Epoch: 22/50 	Training Loss: 0.195023 	Validation Loss: 0.108906
# Epoch: 23/50 	Training Loss: 0.195701 	Validation Loss: 0.108411
# Epoch: 24/50 	Training Loss: 0.191748 	Validation Loss: 0.109743
# Epoch: 25/50 	Training Loss: 0.196822 	Validation Loss: 0.112175
# Epoch: 26/50 	Training Loss: 0.195944 	Validation Loss: 0.108909
# Epoch: 27/50 	Training Loss: 0.197657 	Validation Loss: 0.109238
# Epoch: 28/50 	Training Loss: 0.196428 	Validation Loss: 0.111379
# Epoch: 29/50 	Training Loss: 0.193376 	Validation Loss: 0.114773
# Epoch: 30/50 	Training Loss: 0.190457 	Validation Loss: 0.111173
# Epoch: 31/50 	Training Loss: 0.195108 	Validation Loss: 0.113227
# Epoch: 32/50 	Training Loss: 0.195549 	Validation Loss: 0.114781
# Epoch: 33/50 	Training Loss: 0.196013 	Validation Loss: 0.110654
# Epoch: 34/50 	Training Loss: 0.194377 	Validation Loss: 0.111540
# Epoch: 35/50 	Training Loss: 0.193471 	Validation Loss: 0.109847
# Epoch: 36/50 	Training Loss: 0.194595 	Validation Loss: 0.113846
# Epoch: 37/50 	Training Loss: 0.196425 	Validation Loss: 0.106168
# Epoch: 38/50 	Training Loss: 0.191607 	Validation Loss: 0.107890
# Epoch: 39/50 	Training Loss: 0.195050 	Validation Loss: 0.110016
# Epoch: 40/50 	Training Loss: 0.193329 	Validation Loss: 0.116857
# Epoch: 41/50 	Training Loss: 0.195987 	Validation Loss: 0.109491
# Epoch: 42/50 	Training Loss: 0.196970 	Validation Loss: 0.111109
# Epoch: 43/50 	Training Loss: 0.196327 	Validation Loss: 0.110449
# Epoch: 44/50 	Training Loss: 0.193148 	Validation Loss: 0.113250
# Epoch: 45/50 	Training Loss: 0.192980 	Validation Loss: 0.111238
# Epoch: 46/50 	Training Loss: 0.190373 	Validation Loss: 0.110132
# Epoch: 47/50 	Training Loss: 0.194263 	Validation Loss: 0.110793
# Epoch: 48/50 	Training Loss: 0.192112 	Validation Loss: 0.109656
# Epoch: 49/50 	Training Loss: 0.189843 	Validation Loss: 0.109733
# Epoch: 50/50 	Training Loss: 0.196103 	Validation Loss: 0.110718
# Finished Training for fold 5/5

# %%
# since now we're testing (not training), we set no_grad to NOT calculate the gradients
with torch.no_grad():
    test_images = test_images.to(device)
    # calculate outputs by running images through the network
    outputs = model(test_images)
    # the class with the highest probability is what we choose as prediction
    _, predicted = torch.max(outputs.data, 1)
    predicted = np.array([classes[i] for i in predicted])

submission = pd.DataFrame()
submission['label'] = predicted
submission.to_csv("kFold_50_lrs.csv", index=True, index_label='id')
submission
# Out:
#       label
# 0       cat
# 1       dog
# 2      frog
# 3      bird
# 4     truck
# ...     ...
# 4995   deer
# 4996   ship
# 4997  plane
# 4998    dog
# 4999   bird
#
# [5000 rows x 1 columns]
