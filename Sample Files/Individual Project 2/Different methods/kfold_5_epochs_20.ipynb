# %% [markdown]
# ## Import Statements

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd

# %% [markdown]
# ## Device Config

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device : {device}")
# Out:
# Device : cuda

# %% [markdown]
# ## Set the Seed for reproducibility

# %%
# Set the random seed for reproducibility
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ## Define number of folds

# %%
# Define the number of folds (k)
k = 5  # You can change this value as needed

# %% [markdown]
# ## CNN

# %%
# Define your CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(512, 10)  # 10 classes for CIFAR-10
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Data Prep

# %%
# Define data augmentation and preprocessing transformations
batch_size = 20
augmentation_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(32, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load the CIFAR-10 dataset
augmented_train_data = torchvision.datasets.CIFAR10('data', train=True, download=True, transform=augmentation_transform)

# Split the dataset into k folds
fold_size = len(augmented_train_data) // k
fold_datasets = [torch.utils.data.Subset(augmented_train_data, range(i * fold_size, (i + 1) * fold_size)) for i in range(k)]

# 10 classes in total
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Test set

# %%
# load test data (note that the data has been transformed already)
test_images = torch.load('/kaggle/input/fall-2023-ist-557-individual-project-ii/test_image.pt')

# %% [markdown]
# ## Training Loop

# %%
# Lists to store performance metrics
all_fold_train_losses = []
all_fold_val_losses = []

# Initialize your model
model = CNN()
model.to(device)

for fold_idx, fold_data in enumerate(fold_datasets):
    print(f"Training fold {fold_idx + 1}/{k}")

    # Create data loaders for training and validation
    validation_set = fold_data
    training_sets = [f for i, f in enumerate(fold_datasets) if i != fold_idx]
    training_set = torch.utils.data.ConcatDataset(training_sets)

    train_loader = DataLoader(training_set, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_loader = DataLoader(validation_set, batch_size=batch_size, shuffle=False, num_workers=2)

    

    # Initialize optimizer and loss function
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01)

    # Training loop
    train_losses = []
    val_losses = []
    total_epoch = 20  # You can change the number of epochs as needed

    for epoch in range(total_epoch):
        train_loss = 0.0
        valid_loss = 0.0

        # Train the model
        model.train()
        for data, target in train_loader:
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * data.size(0)

        # Validate the model
        model.eval()
        for valid_data, valid_target in valid_loader:
            valid_data, valid_target = valid_data.to(device), valid_target.to(device)
            valid_output = model(valid_data)
            loss = criterion(valid_output, valid_target)
            valid_loss += loss.item() * valid_data.size(0)

        avg_val_loss = valid_loss / len(validation_set)
        avg_train_loss = train_loss / len(training_set)

        val_losses.append(avg_val_loss)
        train_losses.append(avg_train_loss)

        print(f'Epoch: {epoch + 1}/{total_epoch} \tTraining Loss: {avg_train_loss:.6f} \tValidation Loss: {avg_val_loss:.6f}')

    print(f'Finished Training for fold {fold_idx + 1}/{k}')
    all_fold_train_losses.append(train_losses)
    all_fold_val_losses.append(val_losses)

# Calculate and print the average performance metrics over all folds
avg_train_losses = np.mean(all_fold_train_losses, axis=0)
avg_val_losses = np.mean(all_fold_val_losses, axis=0)

# Plot the training and validation loss curves
import matplotlib.pyplot as plt

plt.plot(range(1, total_epoch + 1), avg_train_losses, label='Average Train Loss', marker='o')
plt.plot(range(1, total_epoch + 1), avg_val_losses, label='Average Validation Loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(f'Average Training and Validation Loss Curves ({k}-fold cross-validation)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training fold 1/5
# Epoch: 1/20 	Training Loss: 1.456838 	Validation Loss: 1.226934
# Epoch: 2/20 	Training Loss: 1.108588 	Validation Loss: 1.091666
# Epoch: 3/20 	Training Loss: 0.952623 	Validation Loss: 0.914939
# Epoch: 4/20 	Training Loss: 0.847677 	Validation Loss: 0.766541
# Epoch: 5/20 	Training Loss: 0.771299 	Validation Loss: 0.718082
# Epoch: 6/20 	Training Loss: 0.708111 	Validation Loss: 0.816264
# Epoch: 7/20 	Training Loss: 0.661570 	Validation Loss: 0.709176
# Epoch: 8/20 	Training Loss: 0.622545 	Validation Loss: 0.609999
# Epoch: 9/20 	Training Loss: 0.592747 	Validation Loss: 0.610020
# Epoch: 10/20 	Training Loss: 0.564528 	Validation Loss: 0.621104
# Epoch: 11/20 	Training Loss: 0.532164 	Validation Loss: 0.544172
# Epoch: 12/20 	Training Loss: 0.510575 	Validation Loss: 0.591792
# Epoch: 13/20 	Training Loss: 0.485726 	Validation Loss: 0.552544
# Epoch: 14/20 	Training Loss: 0.466017 	Validation Loss: 0.566820
# Epoch: 15/20 	Training Loss: 0.444674 	Validation Loss: 0.549998
# Epoch: 16/20 	Training Loss: 0.430257 	Validation Loss: 0.493553
# Epoch: 17/20 	Training Loss: 0.415072 	Validation Loss: 0.510543
# Epoch: 18/20 	Training Loss: 0.398763 	Validation Loss: 0.461255
# Epoch: 19/20 	Training Loss: 0.383875 	Validation Loss: 0.476376
# Epoch: 20/20 	Training Loss: 0.372582 	Validation Loss: 0.459667
# Finished Training for fold 1/5
# Training fold 2/5
# Epoch: 1/20 	Training Loss: 0.398100 	Validation Loss: 0.334661
# Epoch: 2/20 	Training Loss: 0.374521 	Validation Loss: 0.324654
# Epoch: 3/20 	Training Loss: 0.362080 	Validation Loss: 0.352081
# Epoch: 4/20 	Training Loss: 0.346613 	Validation Loss: 0.364505
# Epoch: 5/20 	Training Loss: 0.332171 	Validation Loss: 0.340358
# Epoch: 6/20 	Training Loss: 0.322793 	Validation Loss: 0.354130
# Epoch: 7/20 	Training Loss: 0.310778 	Validation Loss: 0.355342
# Epoch: 8/20 	Training Loss: 0.298641 	Validation Loss: 0.375801
# Epoch: 9/20 	Training Loss: 0.291338 	Validation Loss: 0.383012
# Epoch: 10/20 	Training Loss: 0.277371 	Validation Loss: 0.378493
# Epoch: 11/20 	Training Loss: 0.275470 	Validation Loss: 0.332537
# Epoch: 12/20 	Training Loss: 0.259269 	Validation Loss: 0.355881
# Epoch: 13/20 	Training Loss: 0.251374 	Validation Loss: 0.406521
# Epoch: 14/20 	Training Loss: 0.249571 	Validation Loss: 0.349961
# Epoch: 15/20 	Training Loss: 0.240224 	Validation Loss: 0.338728
# Epoch: 16/20 	Training Loss: 0.231031 	Validation Loss: 0.338975
# Epoch: 17/20 	Training Loss: 0.221990 	Validation Loss: 0.345450
# Epoch: 18/20 	Training Loss: 0.218439 	Validation Loss: 0.332827
# Epoch: 19/20 	Training Loss: 0.210472 	Validation Loss: 0.341445
# Epoch: 20/20 	Training Loss: 0.208990 	Validation Loss: 0.341155
# Finished Training for fold 2/5
# Training fold 3/5
# Epoch: 1/20 	Training Loss: 0.248223 	Validation Loss: 0.184127
# Epoch: 2/20 	Training Loss: 0.229802 	Validation Loss: 0.211772
# Epoch: 3/20 	Training Loss: 0.224230 	Validation Loss: 0.200223
# Epoch: 4/20 	Training Loss: 0.216856 	Validation Loss: 0.174151
# Epoch: 5/20 	Training Loss: 0.205132 	Validation Loss: 0.202518
# Epoch: 6/20 	Training Loss: 0.195655 	Validation Loss: 0.209851
# Epoch: 7/20 	Training Loss: 0.193196 	Validation Loss: 0.219410
# Epoch: 8/20 	Training Loss: 0.187537 	Validation Loss: 0.207978
# Epoch: 9/20 	Training Loss: 0.177186 	Validation Loss: 0.253720
# Epoch: 10/20 	Training Loss: 0.174841 	Validation Loss: 0.228912
# Epoch: 11/20 	Training Loss: 0.168452 	Validation Loss: 0.251072
# Epoch: 12/20 	Training Loss: 0.164132 	Validation Loss: 0.241061
# Epoch: 13/20 	Training Loss: 0.160481 	Validation Loss: 0.205147
# Epoch: 14/20 	Training Loss: 0.154845 	Validation Loss: 0.263021
# Epoch: 15/20 	Training Loss: 0.155233 	Validation Loss: 0.251422
# Epoch: 16/20 	Training Loss: 0.146770 	Validation Loss: 0.212536
# Epoch: 17/20 	Training Loss: 0.141121 	Validation Loss: 0.223993
# Epoch: 18/20 	Training Loss: 0.139026 	Validation Loss: 0.215900
# Epoch: 19/20 	Training Loss: 0.132195 	Validation Loss: 0.215544
# Epoch: 20/20 	Training Loss: 0.130854 	Validation Loss: 0.250111
# Finished Training for fold 3/5
# Training fold 4/5
# Epoch: 1/20 	Training Loss: 0.167001 	Validation Loss: 0.140785
# Epoch: 2/20 	Training Loss: 0.148375 	Validation Loss: 0.122400
# Epoch: 3/20 	Training Loss: 0.143453 	Validation Loss: 0.113724
# Epoch: 4/20 	Training Loss: 0.132166 	Validation Loss: 0.136060
# Epoch: 5/20 	Training Loss: 0.133436 	Validation Loss: 0.141490
# Epoch: 6/20 	Training Loss: 0.130833 	Validation Loss: 0.135560
# Epoch: 7/20 	Training Loss: 0.122878 	Validation Loss: 0.144700
# Epoch: 8/20 	Training Loss: 0.116824 	Validation Loss: 0.172092
# Epoch: 9/20 	Training Loss: 0.115455 	Validation Loss: 0.183867
# Epoch: 10/20 	Training Loss: 0.111740 	Validation Loss: 0.134268
# Epoch: 11/20 	Training Loss: 0.107463 	Validation Loss: 0.133276
# Epoch: 12/20 	Training Loss: 0.109594 	Validation Loss: 0.148234
# Epoch: 13/20 	Training Loss: 0.105733 	Validation Loss: 0.192100
# Epoch: 14/20 	Training Loss: 0.101104 	Validation Loss: 0.139835
# Epoch: 15/20 	Training Loss: 0.098467 	Validation Loss: 0.203955
# Epoch: 16/20 	Training Loss: 0.094987 	Validation Loss: 0.151935
# Epoch: 17/20 	Training Loss: 0.091442 	Validation Loss: 0.153286
# Epoch: 18/20 	Training Loss: 0.092869 	Validation Loss: 0.139101
# Epoch: 19/20 	Training Loss: 0.088404 	Validation Loss: 0.161495
# Epoch: 20/20 	Training Loss: 0.088619 	Validation Loss: 0.140080
# Finished Training for fold 4/5
# Training fold 5/5
# Epoch: 1/20 	Training Loss: 0.119744 	Validation Loss: 0.064604
# Epoch: 2/20 	Training Loss: 0.107459 	Validation Loss: 0.064998
# Epoch: 3/20 	Training Loss: 0.097765 	Validation Loss: 0.078654
# Epoch: 4/20 	Training Loss: 0.095378 	Validation Loss: 0.060800
# Epoch: 5/20 	Training Loss: 0.095447 	Validation Loss: 0.090679
# Epoch: 6/20 	Training Loss: 0.094446 	Validation Loss: 0.074782
# Epoch: 7/20 	Training Loss: 0.089080 	Validation Loss: 0.086554
# Epoch: 8/20 	Training Loss: 0.086935 	Validation Loss: 0.082455
# Epoch: 9/20 	Training Loss: 0.085538 	Validation Loss: 0.076426
# Epoch: 10/20 	Training Loss: 0.079971 	Validation Loss: 0.082425
# Epoch: 11/20 	Training Loss: 0.078755 	Validation Loss: 0.095426
# Epoch: 12/20 	Training Loss: 0.078734 	Validation Loss: 0.078034
# Epoch: 13/20 	Training Loss: 0.079176 	Validation Loss: 0.087553
# Epoch: 14/20 	Training Loss: 0.073117 	Validation Loss: 0.096702
# Epoch: 15/20 	Training Loss: 0.072553 	Validation Loss: 0.084574
# Epoch: 16/20 	Training Loss: 0.073553 	Validation Loss: 0.092301
# Epoch: 17/20 	Training Loss: 0.068854 	Validation Loss: 0.093202
# Epoch: 18/20 	Training Loss: 0.068531 	Validation Loss: 0.088092
# Epoch: 19/20 	Training Loss: 0.067743 	Validation Loss: 0.130466
# Epoch: 20/20 	Training Loss: 0.062342 	Validation Loss: 0.092741
# Finished Training for fold 5/5

# %%
# since now we're testing (not training), we set no_grad to NOT calculate the gradients
with torch.no_grad():
    test_images = test_images.to(device)
    # calculate outputs by running images through the network
    outputs = model(test_images)
    # the class with the highest probability is what we choose as prediction
    _, predicted = torch.max(outputs.data, 1)
    predicted = np.array([classes[i] for i in predicted])

submission = pd.DataFrame()
submission['label'] = predicted
submission.to_csv("kFold.csv", index=True, index_label='id')
submission
# Out:
#       label
# 0       cat
# 1       dog
# 2      frog
# 3       dog
# 4     truck
# ...     ...
# 4995  horse
# 4996   ship
# 4997  plane
# 4998    dog
# 4999   bird
#
# [5000 rows x 1 columns]
